# %%
import numpy as np
import time
import cv2
import math

labelsPath = "./coco.names"
LABELS = open(labelsPath).read().strip().split("\n")

np.random.seed(42)
COLORS = np.random.randint(0, 255, size=(len(LABELS), 3),
	dtype="uint8")

weightsPath = "./yolov3.weights"
configPath = "./yolov3.cfg"

net = cv2.dnn.readNetFromDarknet(configPath, weightsPath)





cap = cv2.VideoCapture(0)

width=int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height=int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))

writer=cv2.VideoWriter("Output.mp4",cv2.VideoWriter_fourcc(*'DIVX'),20,(width,height))

while(cap.isOpened()):
    
    ret,image=cap.read()
    (H, W) = image.shape[:2]
    ln = net.getLayerNames()
    ln = [ln[i[0] - 1] for i in net.getUnconnectedOutLayers()]
    blob = cv2.dnn.blobFromImage(image, 1 / 255.0, (416, 416),swapRB=True, crop=False)
    net.setInput(blob)
    start = time.time()
    layerOutputs = net.forward(ln)
    end = time.time()
    print("Frame Prediction Time : {:.6f} seconds".format(end - start))
    boxes = []
    confidences = []
    classIDs = []
    for output in layerOutputs:
        for detection in output:
            scores = detection[5:]
            classID = np.argmax(scores)
            confidence = scores[classID]
            if confidence > 0.1 and classID == 0:
                box = detection[0:4] * np.array([W, H, W, H])
                (centerX, centerY, width, height) = box.astype("int")
                x = int(centerX - (width / 2))
                y = int(centerY - (height / 2))
                boxes.append([x, y, int(width), int(height)])
                confidences.append(float(confidence))
                classIDs.append(classID)
                
    idxs = cv2.dnn.NMSBoxes(boxes, confidences, 0.5,0.3)
    ind = []
    for i in range(0,len(classIDs)):
        if(classIDs[i]==0):
            ind.append(i)
    a = []
    b = []

    if len(idxs) > 0:
            for i in idxs.flatten():
                (x, y) = (boxes[i][0], boxes[i][1])
                (w, h) = (boxes[i][2], boxes[i][3])
                a.append(x)
                b.append(y)
                
    distance=[] 
    nsd = []
    for i in range(0,len(a)-1):
        for k in range(1,len(a)):
            if(k==i):
                break
            else:
                x_dist = (a[k] - a[i])
                y_dist = (b[k] - b[i])
                d = math.sqrt(x_dist * x_dist + y_dist * y_dist)
                distance.append(d)
                if(d <=100):
                    nsd.append(i)
                    nsd.append(k)
                nsd = list(dict.fromkeys(nsd))
                print(nsd)
    color = (0, 0, 255) 
    for i in nsd:
        (x, y) = (boxes[i][0], boxes[i][1])
        (w, h) = (boxes[i][2], boxes[i][3])
        cv2.rectangle(image, (x, y), (x + w, y + h), color, 2)
        text = "Danger Zone"
        cv2.putText(image, text, (x, y - 5), cv2.FONT_HERSHEY_SIMPLEX,0.5, color, 2)
    color = (0, 255, 0) 
    if len(idxs) > 0:
        for i in idxs.flatten():
            if (i in nsd):
                break
            else:
                (x, y) = (boxes[i][0], boxes[i][1])
                (w, h) = (boxes[i][2], boxes[i][3])
                cv2.rectangle(image, (x, y), (x + w, y + h), color, 2)
                text = 'Safe Zone'
                cv2.putText(image, text, (x, y - 5), cv2.FONT_HERSHEY_SIMPLEX,0.5, color, 2)   
                writer.write(image)
    
    cv2.imshow("Social Distancing Detector", image)
    
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break
cap.release()
writer.release()
cv2.destroyAllWindows()
# Out:
# Frame Prediction Time : 2.251692 seconds
# Frame Prediction Time : 1.656049 seconds
# Frame Prediction Time : 1.619068 seconds
# Frame Prediction Time : 1.528124 seconds
# Frame Prediction Time : 1.513127 seconds
# Frame Prediction Time : 1.446167 seconds
# []
# Frame Prediction Time : 1.451167 seconds
# Frame Prediction Time : 1.468156 seconds
# Frame Prediction Time : 1.441171 seconds
# Frame Prediction Time : 1.472152 seconds
# Frame Prediction Time : 1.785975 seconds
# Frame Prediction Time : 1.519129 seconds
# Frame Prediction Time : 1.610073 seconds
# Frame Prediction Time : 1.508131 seconds
# Frame Prediction Time : 1.515131 seconds
# Frame Prediction Time : 1.376194 seconds
# Frame Prediction Time : 1.356215 seconds
# Frame Prediction Time : 1.491143 seconds
# Frame Prediction Time : 1.520125 seconds
# Frame Prediction Time : 1.647054 seconds
# Frame Prediction Time : 1.480149 seconds
# Frame Prediction Time : 1.577095 seconds
# Frame Prediction Time : 1.502132 seconds
# Frame Prediction Time : 1.610072 seconds
# Frame Prediction Time : 1.628062 seconds
# Frame Prediction Time : 1.483148 seconds
# Frame Prediction Time : 1.470145 seconds
# Frame Prediction Time : 1.483144 seconds
# Frame Prediction Time : 1.738013 seconds
# Frame Prediction Time : 1.687029 seconds
# Frame Prediction Time : 1.469156 seconds
# Frame Prediction Time : 1.437178 seconds
# Frame Prediction Time : 1.595081 seconds
# Frame Prediction Time : 1.592083 seconds
# Frame Prediction Time : 1.454160 seconds
# Frame Prediction Time : 1.477145 seconds
# Frame Prediction Time : 1.623061 seconds
# Frame Prediction Time : 1.579093 seconds
# Frame Prediction Time : 1.566096 seconds
# Frame Prediction Time : 1.619071 seconds
# Frame Prediction Time : 1.653048 seconds
# Frame Prediction Time : 1.594086 seconds
# Frame Prediction Time : 1.618575 seconds
# Frame Prediction Time : 1.590083 seconds
# Frame Prediction Time : 1.565093 seconds
# Frame Prediction Time : 1.627065 seconds
# Frame Prediction Time : 1.619072 seconds
# Frame Prediction Time : 1.578092 seconds
# Frame Prediction Time : 1.594055 seconds
# Frame Prediction Time : 1.577095 seconds
# Frame Prediction Time : 1.557104 seconds
# Frame Prediction Time : 1.595086 seconds
# Frame Prediction Time : 1.515130 seconds
# Frame Prediction Time : 1.590087 seconds
# Frame Prediction Time : 1.586087 seconds
# Frame Prediction Time : 1.613067 seconds
# Frame Prediction Time : 1.596084 seconds
# Frame Prediction Time : 1.569096 seconds
# Frame Prediction Time : 1.604079 seconds
# Frame Prediction Time : 1.573094 seconds
# Frame Prediction Time : 1.602077 seconds
# Frame Prediction Time : 1.589087 seconds
# Frame Prediction Time : 1.620068 seconds
# Frame Prediction Time : 1.581093 seconds
# Frame Prediction Time : 1.569102 seconds
# Frame Prediction Time : 1.588091 seconds
# Frame Prediction Time : 1.641051 seconds
# Frame Prediction Time : 1.599082 seconds
# Frame Prediction Time : 1.598080 seconds
# Frame Prediction Time : 1.676029 seconds
# Frame Prediction Time : 1.550108 seconds
# Frame Prediction Time : 1.592085 seconds
# Frame Prediction Time : 1.615072 seconds
# Frame Prediction Time : 1.614065 seconds
# Frame Prediction Time : 1.571100 seconds
# Frame Prediction Time : 1.606076 seconds
# Frame Prediction Time : 1.620069 seconds
# Frame Prediction Time : 1.564099 seconds
# Frame Prediction Time : 1.572098 seconds
# Frame Prediction Time : 1.593078 seconds
# Frame Prediction Time : 1.614069 seconds
# Frame Prediction Time : 1.590086 seconds
# Frame Prediction Time : 1.634061 seconds
# Frame Prediction Time : 1.572086 seconds
# Frame Prediction Time : 1.590086 seconds
# Frame Prediction Time : 1.597078 seconds
# Frame Prediction Time : 1.571093 seconds
# Frame Prediction Time : 1.602082 seconds
# Frame Prediction Time : 1.494142 seconds
# Frame Prediction Time : 1.635059 seconds
# Frame Prediction Time : 1.607076 seconds
# Frame Prediction Time : 1.571099 seconds
# Frame Prediction Time : 1.591083 seconds
# Frame Prediction Time : 1.576095 seconds
# Frame Prediction Time : 1.607071 seconds
# Frame Prediction Time : 1.568096 seconds
# Frame Prediction Time : 1.628065 seconds
